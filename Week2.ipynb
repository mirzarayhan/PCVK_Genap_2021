# %% [markdown]
# <a href="https://colab.research.google.com/github/mirzarayhan/PCVK_Genap_2021/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# akses ke gdrive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img =cv.imread('/content/drive/MyDrive/Gambar/hguc-crossbone-gundam-x0-full-cloth.jpg') #direktori dari gdrive
plt.imshow(img) # hasil berupa gambar bgr

# %%
img2 = img
img3 =cv.cvtColor(img,cv.COLOR_BGR2RGB) #konversi dari bgr ke rgb
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/Gambar/hguc-crossbone-gundam-x0-full-cloth.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#menampilkan plot dengan ukuran kanvas lebih besar

fig = plt.figure(figsize=(10,10)) # ubah sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=(50),color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# Tugas 1
# 1. Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga
# berubah?
# 2. Tampilkan image dalam channel Red-Green dan Green-Blue saja!
# 3. Tampilkan image baris ke 20-250, kolom 20-250!
# 4. Tampilkan image baris ke 7-27, semua kolom, channel Red saja!
# 5. Buat 3 kotak berbagai ukuran dan warna yang berbeda dalam satu image.
# disarankan menggunakan bilangan acak/random!

# %%
# No 1. Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga berubah? 
img =cv.imread('/content/drive/MyDrive/Gambar/hguc-crossbone-gundam-x0-full-cloth.jpg') 
img =cv.cvtColor(img,cv.COLOR_BGR2RGB)
fig = plt.figure(figsize=(5,5))
plt.imshow(img)

# hasil = tidak berubah sama sekali

# %%
# No 2.Tampilkan image dalam channel Red-Green dan Green-Blue saja!

img2 =cv.imread('/content/drive/MyDrive/Gambar/hguc-crossbone-gundam-x0-full-cloth.jpg') 
img2 =cv.cvtColor(img2,cv.COLOR_BGR2RGB)
cyan = img2.copy()
cyan[:,:,0] = 0 # Green-Blue channel

plt.imshow(cyan)

# %%
yellow = img2.copy()
yellow[:,:,2] = 0 # Red-Green channel

plt.imshow(yellow)

# %%
# No 3.Tampilkan image baris ke 20-250, kolom 20-250!

croppedImg = img[20:250, 20:250]
plt.imshow(croppedImg)

# NB : Background Berwarna hitam

# %%
# No 4. Tampilkan image baris ke 7-27, semua kolom, channel Red saja!
#Jujur saya kurang paham atas baris dan kolom di konteks ini
croppedImg = img[7:27, 0:1200]
plt.imshow(croppedImg)

# %%
croppedImg = img[0:1200, 7:27]
plt.imshow(croppedImg)

# %%
# No 5. Buat 3 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random!
img10 =cv.imread('/content/drive/MyDrive/Gambar/hguc-crossbone-gundam-x0-full-cloth.jpg') 
img10 =cv.cvtColor(img10,cv.COLOR_BGR2RGB) 

cv.rectangle(img10,pt1=(200,400),pt2=(400,650),color=(40,255,100),thickness=10) #y1x1 y2x2
cv.rectangle(img10,pt1=(1000,800),pt2=(400,1100),color=(150,200,10),thickness=10)
cv.rectangle(img10,pt1=(440,450),pt2=(650,240),color=(100,80,200),thickness=10)
plt.imshow(img10)

# %% [markdown]
# Tugas 2
#
# Berdasarkan praktikum bagian 3 dan 4 kerjakan beberapa tugas berikut :
# 1. Buat rectangle dan circle pada bagian wajah dari image foto anda saat
# beraktifitas (bukan pasfoto).
# 2. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB
# dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!
# 3. Tulis nama file pada file citra dari soal no.2. Gunakan font, ukuran font, dan warna font yang sesuai keinginan anda.

# %%
# No 1. Buat rectangle dan circle pada bagian wajah dari image foto anda saat beraktifitas (bukan pasfoto).
aku =cv.imread('/content/drive/MyDrive/Gambar/aku.jpeg') 
aku =cv.cvtColor(aku,cv.COLOR_BGR2RGB) 
cv.rectangle(aku,pt1=(500,300),pt2=(610,150),color=(150,200,10),thickness=10) #y1x1 y2x2
cv.circle(aku,center=(550,210),radius=(100),color=(255,80,77),thickness=8)
plt.imshow(aku)

# %%
# No 2. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!
sailboat =cv.imread('/content/drive/MyDrive/Gambar/sailboat.jpg') 
sailboat =cv.cvtColor(sailboat,cv.COLOR_BGR2RGB)
sailboat[:,:,0] = 0
sailboat[:,:,1] = 0
cv.rectangle(sailboat,pt1=(9,1750),pt2=(250,1908),color=(150,200,10),thickness=30) #y1x1 y2x2

# No 3.Tulis nama file pada file citra dari soal no.2. Gunakan font, ukuran font, dan warna font yang sesuai keinginan anda.

font = cv.FONT_ITALIC
cv.putText(sailboat,text='Ngapal Bro!',org=(350,1000),fontFace=font,fontScale=4,color=(255,255,0),thickness=20,lineType=cv.LINE_AA)
plt.imshow(sailboat)

# %% [markdown]
# Pertanyaan
#
#
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
#
#   Jika menggunakan cv2_imshow maka gambar akan langsung keluar dengan ukuran resolusi sebenarnya dan memakai RGB
#
#   Sedangkan menggunakan matplotlib maka gambar akan diberi sumbu x dan y dan disumbu tsb terdapat kolom dan baris yang mewakilkan resolusi, dan gambar akan menggunakana BGR
#
#
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16
# dan int32?
#
#   Menentukan alokasi data yang digunakan oleh black image tsb
#
# 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode
# berikut
#
#    Karena cv.imshow tidak berjalan di Google Colab
#
# 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3
#
#   skimage import io yaitu baris kode untuk mengimpor library scikit-image untuk memproses gambar menggunakan numpy
